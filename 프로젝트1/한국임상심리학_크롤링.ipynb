# %%
#웹 크롤링에 사용될 모듈
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
from pprint import pprint

#기타
import re
import json
from geopy.geocoders import Nominatim

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 13.9 MB/s eta 0:00:00
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

api_key= '382b6c78365fb2bce83b5cd327ecbfbb'
def addr_to_lat_lon(addr):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={address}'.format(address=addr)
    headers = {"Authorization": "KakaoAK " + api_key}
    try:
        result = json.loads(str(requests.get(url, headers=headers).text))
        match_first = result['documents'][0]['address']
        #위도,경도 반환
        return [float(match_first['x']), float(match_first['y'])]
    except:
        return None
m
total_lst=[]
#페이지 선택
for i in range(1,17):
    url=f'https://www.kcp.or.kr/new/psychologistManagement/list.asp?listType=2&page={i}&rows=15&task=ins&cityi=&gui=&searchText='
    driver.get(url)
    sleep(3)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    #이름이 담긴 태그 선택
    name_lst=soup.select('tr>td[class="text-center vm"]:nth-of-type(2)')
    
     #전화번호와 주소가 담긴 태그를 선택
    phone_and_address= soup.select('td>ul>li>small')
    
    #홀수번째 요소에 전화번호, 짝수번째 요소에 주소가 담김
    phone_lst=phone_and_address[0::2]
    address_lst=phone_and_address[1::2]
    
    #리스트를 문자열로 전환후 <tag_name>을 제거하고, strip을 통해 []을 제거한다. 그후 다시 split을 통해
    #,를 경계로 리스트로 만든다
    # phone_lst=(re.sub('<.+?>', '', phone_lst_source, 0).strip().strip('['']')).split(',')
    # address_lst=(re.sub('<.+?>', '', address_lst_source, 0).strip().strip('['']')).split(',')
    
    # json파일형식으로 데이터를 저장하기 위한 루프문
    for j in range(len(name_lst)):
        temp= {}
        temp['공공/민간']='민간'
        temp['기관구분']='상담소'
        temp['기관명']=re.sub('<.+?>', '', str(name_lst[j]), 0).strip().replace(u'\xa0', u' ')
        temp['주소']=re.sub('<.+?>', '', str(address_lst[j]), 0).strip()
        temp['좌표']=addr_to_lat_lon(temp['주소'])
        temp['전화번호']=re.sub('<.+?>', '', str(phone_lst[j]), 0).strip()
        temp['홈페이지']= None
        total_lst.append(temp)

res={}
res['정신건강관련기관'] =total_lst   
#json 파일으로 변환하기
res_json= json.dumps(res,ensure_ascii=False)
pprint(res_json)

#json파일로 저장하기
with open('전국_임상심리사_상담소.json','w',encoding='utf-8') as f:
    f.write(res_json)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-12-8baf5dd67ade> in <cell line: 2>()
#       1 service = Service(executable_path=ChromeDriverManager().install())
# ----> 2 driver = webdriver.Chrome(service=service)
#       3
#       4 api_key= '382b6c78365fb2bce83b5cd327ecbfbb'
#       5 def addr_to_lat_lon(addr):
#
# ~/venv/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67             service = Service(executable_path, port, service_args, service_log_path)
#      68
# ---> 69         super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                          port, options,
#      71                          service_args, desired_capabilities,
#
# ~/venv/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      87
#      88         self.service = service
# ---> 89         self.service.start()
#      90
#      91         try:
#
# ~/venv/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      96         count = 0
#      97         while True:
# ---> 98             self.assert_process_still_running()
#      99             if self.is_connectable():
#     100                 break
#
# ~/venv/lib/python3.9/site-packages/selenium/webdriver/common/service.py in assert_process_still_running(self)
#     108         return_code = self.process.poll()
#     109         if return_code:
# --> 110             raise WebDriverException(
#     111                 'Service %s unexpectedly exited. Status code was: %s'
#     112                 % (self.path, return_code)
#
# WebDriverException: Message: Service /root/.wdm/drivers/chromedriver/linux64/103.0.5060/chromedriver unexpectedly exited. Status code was: 127

# %% [raw]
# total_lst

# %%
total_lst
# Out:
# [{'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '(주)마음꼭 차심리상담센터 차심리상담센터',
#   '주소': '경기도 성남시 분당구 야탑동 351 기억력센터 2층 (야탑로 59 분당차병원)',
#   '좌표': [127.125249531488, 37.4102499478694],
#   '전화번호': '031-780-5437',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '(주)마음꼭 차심리상담센터',
#   '주소': '경기도 성남시 분당구 야탑동 351 기억력센터 2층 (야탑로 59 분당차병원)',
#   '좌표': [127.125249531488, 37.4102499478694],
#   '전화번호': '031-780-5437',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '(주)마음연구소 부설 마음iN심리상담센터',
#   '주소': '서울 종로구 종로3길 34 6층',
#   '좌표': [126.979481465774, 37.5718747898899],
#   '전화번호': '02-722-2883',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '(주)엠브레스마인드심리상담센터송도',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '032-832-2143',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '가능성연구소',
#   '주소': '부산시 해운대구 세실로79 부산해운대대교사옥 6층',
#   '좌표': [129.176440231179, 35.1716471915662],
#   '전화번호': '051-704-8610',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '가톨릭대학교 은평성모병원',
#   '주소': '서울 은평구 진관동 93-6',
#   '좌표': [126.916547294959, 37.6332509998197],
#   '전화번호': '02-1811-7755',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '강박사마음&amp;학습상담센터 강박사심리센터',
#   '주소': '부산시 수영구 연수로 332 대한빌딩 4층 501호',
#   '좌표': None,
#   '전화번호': '051-703-2870',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '강원대학교병원 정신건강의학과',
#   '주소': '강원도 춘천시 백령로 156 강원대학교병원 정신건강의학과',
#   '좌표': [127.744801430864, 37.8747012284547],
#   '전화번호': '033-258-2437',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '건국대학교 인권센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '02-450-0578',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '경기도고양교육지원청 Wee센터',
#   '주소': '경기도 고양시 일산동구 장대길 64-27',
#   '좌표': [126.769592625121, 37.6387498491218],
#   '전화번호': '070-4459-7196',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '경기도아동보호전문기관',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-5099-8713',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '경성대학교 일반대학원 심리학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '경운대학교 상담복지학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '경인심리건강센터 경인심리건강센터',
#   '주소': '경기 부천시 중동로248번길 52 네이버시티 201-1호',
#   '좌표': [126.771637397229, 37.5011829186934],
#   '전화번호': '032-321-2841',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '고나영 심리상담연구소',
#   '주소': '원주시 입춘로 110 파라다이스프라자 3층 고나영 심리상담연구소',
#   '좌표': [127.981672859909, 37.3234153056704],
#   '전화번호': '033-733-2074',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '고려대학교 학생상담센터',
#   '주소': '서울특별시 성북구 안암로 145 고려대학교 중앙광장 B114',
#   '좌표': [127.031698331241, 37.5887034223667],
#   '전화번호': '02-3290-1540',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '고은정 심리상담센터 [보듬과 아우름] 고은정 심리상담센터 [보듬과 아우름]',
#   '주소': '서울 양천구 목동 오목로 345 슬로우스퀘어 318호',
#   '좌표': [126.875820730078, 37.5247775349288],
#   '전화번호': '02-2642-3375',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '과천 임상심리연구소',
#   '주소': '경기도 과천시 중앙로 137, 4층 404호 과천 임상심리연구소',
#   '좌표': [126.99173895002, 37.4288054400031],
#   '전화번호': '02-3418-0502',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '광화문 마음공간 심리상담센터',
#   '주소': '서울시 종로구 사직로 8길 34 경희궁의 아침 3단지 오피스텔 211호',
#   '좌표': [126.9724255294, 37.5735877659071],
#   '전화번호': '02-720-7127',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '국가보훈처',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '02-786-7937',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '국방부',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '국방부',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '031-555-7859',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '그로잉마인드',
#   '주소': '세종특별자치시 한누리대로 284',
#   '좌표': [127.257209054662, 36.4895541603231],
#   '전화번호': '010-8410-9520',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '김연 심리상담 연구소',
#   '주소': '(04037) 서울 마포구 양화로 59 (서교동) 화승리버스텔 5층 502호',
#   '좌표': [126.914885960173, 37.5506586876484],
#   '전화번호': '02-336-0707',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '김지연 융 심리분석연구소',
#   '주소': '서울시 서초구 사평대로 154, 101-1215',
#   '좌표': None,
#   '전화번호': '010-3253-0730',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '나로살기심리상담센터',
#   '주소': '경기 광명시 오리로 902 금산빌딩 501호',
#   '좌표': [126.86286916955, 37.4772841925901],
#   '전화번호': '02-6229-0226',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '나무마음심리상담센터',
#   '주소': '서울 강남구 봉은사로 474, 208호 (삼성동 쌍용플래티넘)',
#   '좌표': [127.052026639291, 37.5123672407678],
#   '전화번호': '02-555-7948',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '나무솔심리상담센터 나무솔 심리상담센터',
#   '주소': '인천광역시 서구 청라에메랄드로 102번길, 8. 우성메디피아 709호',
#   '좌표': [126.656820957929, 37.5339796761491],
#   '전화번호': '032-576-0030',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '나사랑심리상담센터',
#   '주소': '서울시 성북구 삼선동2가 22번지 현명빌딩 302호',
#   '좌표': [127.010127723365, 37.5885353347375],
#   '전화번호': '02-747-2131',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '다움심리상담센터',
#   '주소': '서울특별시 영등포구 양평로 16  603호(당산동 6가 당산동 대정프라자)',
#   '좌표': [126.90450018213, 37.5328855588883],
#   '전화번호': '02-2672-1377',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '닥터스 심리아카데미',
#   '주소': '성남대로393 두산위브파빌리온 B동',
#   '좌표': [127.10717141554, 37.3716372837565],
#   '전화번호': '010-7736-0853',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '담은 심리상담센터',
#   '주소': '서울 강서구 마곡서로 152 두산 더 랜드타워 A동 603호',
#   '좌표': [126.82597944995, 37.5676859104888],
#   '전화번호': '010-8330-2766',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '담음심리상담센터',
#   '주소': '경북 포항시 북구 우창동로158번길 4 우현더원테라스 202호',
#   '좌표': [129.36546407321, 36.0622647989625],
#   '전화번호': '010-2157-6654',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '대검찰청',
#   '주소': '서울특별시 서초구 반포대로 157 대검찰청 국가디지털포렌식센터 5층 진술분석실',
#   '좌표': [127.006171611164, 37.4941541668482],
#   '전화번호': '010-8649-8644',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '대검찰청 과학수사부',
#   '주소': '서울특별시 서초구 반포대로 157 대검찰청 NDFC(국가디지털포렌식센터) 심리분석실',
#   '좌표': [127.006171611164, 37.4941541668482],
#   '전화번호': '02-3480-2386',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '대구가톨릭대학교 일반대학원 심리학과',
#   '주소': '경상북도 경산시 하양읍 하양로 13-13 대구가톨릭대학교 사회과학관 심리학과 509호',
#   '좌표': [128.807422033769, 35.9089671138434],
#   '전화번호': '053-850-3289',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '대전대학교 학생상담센터(구. 대전대 리더십카운슬링센터) 대전대학교',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '042-280-2455',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '더봄심리상담연구소',
#   '주소': '인천광역시 미추홀구 아암대로 29번길 16, 용현엑슬루타워',
#   '좌표': [126.638015239648, 37.4566605240214],
#   '전화번호': '010-7373-8963',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '도상금 임상심리센터',
#   '주소': '서울 서초구 서운로 11 서초디오빌 819호',
#   '좌표': [127.029112829918, 37.4849946106957],
#   '전화번호': '02-578-2283',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '동덕여자대학교 일반대학원',
#   '주소': '서울시 성북구 화랑로13길 60 동덕여자대학교 일반대학원 아동·심리학과',
#   '좌표': [127.041176301847, 37.6068148327539],
#   '전화번호': '02-940-4498',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '동명대학교 복지산업대학원 상담심리학과',
#   '주소': '신선로 428 (용당동)  동명대학교 상담심리학과',
#   '좌표': [129.101378162616, 35.124683793781],
#   '전화번호': '051-629-2102',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '동신대학교 상담심리학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '061-330-3535',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '따듯한바람 마음치유소',
#   '주소': '제주시 연삼로 379, 3층',
#   '좌표': [126.532263537976, 33.4941408931009],
#   '전화번호': '010-7469-5558',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '라온혜윰힐링센터',
#   '주소': '경북 경산시 용성면 곡신길 11-5',
#   '좌표': [128.874250869909, 35.7795705925979],
#   '전화번호': '053-961-0050',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '라포심리상담센터',
#   '주소': '영등포구 국제금융로 6길 33(여의도동 36-2) 맨하탄빌딩(구 여의도 백화점) 918호',
#   '좌표': [126.926911965929, 37.5207908297398],
#   '전화번호': '02-780-5501',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '레모네이드 심리상담연구소',
#   '주소': '서울 서초구 서초대로 240 서초동일하이빌 (주상복합) 303호',
#   '좌표': [127.00834349369, 37.4915770626912],
#   '전화번호': '010-3407-6655',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '로뎀심리연구소',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-6783-0525',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '로뎀심리학습상담센터',
#   '주소': '경기도 고양시 일산동구 장항동 771-1 우림로데오스위트 514호,515호',
#   '좌표': [126.770935080298, 37.6599366087868],
#   '전화번호': '031-904-4569',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '루카스병원',
#   '주소': '경기도 부천시 경인로 88 루카스병원',
#   '좌표': [126.764898434303, 37.4836054116636],
#   '전화번호': '032-310-0100',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음공간심리상담센터',
#   '주소': '경기도 수원시 영통구 망포동 417-2 망포센트럴프라자 4층',
#   '좌표': [127.059132645799, 37.2412498536621],
#   '전화번호': '031-202-5055',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음과사람',
#   '주소': '가락로19길 9-5 1층',
#   '좌표': [127.110618855853, 37.5030130373291],
#   '전화번호': '010-4532-6091',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음과학연구소 숨',
#   '주소': '경북 경산시 중산동 펜타힐즈 2로 37, 힐즈스퀘어 3차 602호',
#   '좌표': [128.718679931924, 35.8274631538473],
#   '전화번호': '010-9659-7670',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음그루심리상담센터 마음그루심리상담센터',
#   '주소': '부산시 금정구 중앙대로 2008 예일빌딩 504호',
#   '좌표': [129.092534753063, 35.2635001375329],
#   '전화번호': '051-949-2632',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음달심리상담센터',
#   '주소': '수원시 팔달구 권광로 204 영조아름다운나날 5층 마음달심리상담센터',
#   '좌표': [127.033829691004, 37.2656312163671],
#   '전화번호': '050-4980-1134',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음돌봄연구소',
#   '주소': '서울특별시 중구 동호로 186-7 501호 (신당동, MJ빌딩)',
#   '좌표': [127.011505413679, 37.554605081736],
#   '전화번호': '010-8290-1624',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음동네심리상담센터 마음동네심리상담센터',
#   '주소': '인천시 남동구 구월남로 172 정락빌딩 502호',
#   '좌표': [126.708411493644, 37.4527515329406],
#   '전화번호': '032-431-0088',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음뜨락 임상심리센터',
#   '주소': '서울 성동구 한림말길 48 옥수중앙하이츠APT상가 3층',
#   '좌표': [127.016196963074, 37.5410102614044],
#   '전화번호': '02-2291-7233',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음빛심리상담센터',
#   '주소': '일곡마을로 152번길 3-2',
#   '좌표': [126.891462514935, 35.2096688032537],
#   '전화번호': '010-8403-1225',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음숲심리상담연구소',
#   '주소': '서울시 송파구 백제고분로 63, 711호',
#   '좌표': [127.078885862191, 37.511049234376],
#   '전화번호': '010-8860-3228',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음애심리상담센터',
#   '주소': '부평동 754-92 롯데아이원 402호',
#   '좌표': [126.718682189202, 37.4858254894114],
#   '전화번호': '032-516-8088',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음을 걷는 동반자',
#   '주소': '경기도 용인시 처인구 명지로40번길 35-16',
#   '좌표': [127.182243414418, 37.2306890205109],
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음의 위로 임상심리연구소',
#   '주소': '서울 강남구 논현로 155길 10, 정운빌딩 4층 401호',
#   '좌표': [127.027161335061, 37.5219474762203],
#   '전화번호': '010-9797-0045',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음의소리심리상담센터',
#   '주소': '서울시 서초구 서초1동 1445-4번지 래미안 서초 유니빌 321호',
#   '좌표': [127.016967219084, 37.4846980245878],
#   '전화번호': '02-587-4666',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마음지기 심리상담센터',
#   '주소': '수원시 권선구 권선동 1013번지 지오베르크 1111호',
#   '좌표': [127.029750161455, 37.2616569136098],
#   '전화번호': '031-304-4985',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드레스트 심리상담센터',
#   '주소': '서울특별시 서초구 서초중앙로 5길 10-8 우성쁘띠오피스텔 201호',
#   '좌표': [127.015099594605, 37.4858654442726],
#   '전화번호': '02-585-7158',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드베이킹 심리교육연구소',
#   '주소': '경기도 고양시 덕양구 고양대로 1359-24',
#   '좌표': [126.836382003962, 37.6556705600612],
#   '전화번호': '010-8694-8041',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드빅 상담센터',
#   '주소': '서울시 강남구 삼성로75길 9 영양빌딩 2층',
#   '좌표': [127.057475063799, 37.5033678219291],
#   '전화번호': '02-552-1656',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드업 심리상담연구소',
#   '주소': '서울특별시 양천구 목동서로 155 목동파라곤 105동 2401호',
#   '좌표': [126.875071951863, 37.5299956155624],
#   '전화번호': '02-2648-5412',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드웍스',
#   '주소': '서울특별시 강남구 테헤란로 309 1718호',
#   '좌표': [127.04443196555, 37.5035572530344],
#   '전화번호': '02-501-5150',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드플니스 심리상담연구소',
#   '주소': '서울시 마포구 양화로 125, 경남관광빌딩 4층',
#   '좌표': [126.920309389675, 37.5547493986687],
#   '전화번호': '02-333-4001',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '마인드플러스 심리상담센터',
#   '주소': '대구시 수성구 지범로 111, 202호',
#   '좌표': [128.632790389085, 35.8249649250931],
#   '전화번호': '053-253-2705',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '목포스마일센터',
#   '주소': '전남 목포시 용당로 300 목포스마일센터',
#   '좌표': [126.400270646442, 34.8140678657379],
#   '전화번호': '061-277-1295',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '목포스마일센터',
#   '주소': '전남 목포시 용당로 300 목포스마일센터',
#   '좌표': [126.400270646442, 34.8140678657379],
#   '전화번호': '061-277-1295',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '배재대학교 심리상담학과',
#   '주소': '배재로 155-40(도마동)',
#   '좌표': [127.366074460163, 36.3232382774419],
#   '전화번호': '042-722-2528',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '배화여자대학교 학생상담지원실',
#   '주소': '서울시 종로구 필운대로1길 34',
#   '좌표': [126.967291871532, 37.5795440101952],
#   '전화번호': '02-397-0598',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '백석대학교 상담대학원',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '부산가톨릭대학교',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '051-510-0676',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '부산심리상담센터 함께 부설 트라우마연구소',
#   '주소': '부산시 연제구 중앙대로1131, 연산메디칼센타 1404호',
#   '좌표': [129.080687948905, 35.1885320009779],
#   '전화번호': '010-5486-1404',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '부산지방병무청',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '부평 국제아동발달클리닉',
#   '주소': '인천시 부평구 평천로 396 드림플라자 3층',
#   '좌표': [126.73425935643, 37.5172172806584],
#   '전화번호': '032-524-7770',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '분당서울대학교병원',
#   '주소': '경기도 성남시 분당구 구미로173번길 82',
#   '좌표': [127.124485012105, 37.3520254308069],
#   '전화번호': '031-1588-3369',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '비마이셀프 심리상담소',
#   '주소': '충북 제천시 단양로 27번길',
#   '좌표': None,
#   '전화번호': '010-9479-9876',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성 에스원',
#   '주소': '서울 중구 세종대로9길 41 퍼시픽타원 3층 삼성에스원 마음나눔터',
#   '좌표': [126.97299628821, 37.5613582316301],
#   '전화번호': '02-3789-0913',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성생명',
#   '주소': '서울 서초구 서초대로74길 11 마음건강센터',
#   '좌표': [127.026914460572, 37.4966333557707],
#   '전화번호': '02-722-6526',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성전자',
#   '주소': '충남 아산시 배방읍',
#   '좌표': [127.053945963176, 36.7739148977276],
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성전자 Life Coaching센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성전자',
#   '주소': '경기 평택시 고덕면 삼성로 114',
#   '좌표': None,
#   '전화번호': '070-7034-6681',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '삼성지음심리상담센터',
#   '주소': '인천 광역시 연수구 송도동 컨벤시아대로81 드림시티 3층 329호',
#   '좌표': [126.650165044813, 37.3949423122559],
#   '전화번호': '032-833-0835',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '상담심리연구소 쉼표',
#   '주소': '충남 천안시 동남구 만남로 9',
#   '좌표': [127.153016691692, 36.8191822529134],
#   '전화번호': '010-4734-2285',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '새미래심리건강연구소',
#   '주소': '대구시 달서구 용산로 141 그랜드 M타워',
#   '좌표': [128.530126305596, 35.8501292765145],
#   '전화번호': '053-657-6571',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '새미래심리건강연구소',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '053-657-6571',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울 EMDR 트라우마센터',
#   '주소': '서울시 서초구 강남대로39길 6-21',
#   '좌표': [127.031907220639, 37.4869802518396],
#   '전화번호': '02-587-8824',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울고등법원',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울라운지',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '02-0000-0000',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울북부해바라기센터',
#   '주소': '서울특별시 동대문구 망우로82 서울북부해바라기센터(커뮤니티센터 2층)',
#   '좌표': [127.06355328121, 37.5862119387672],
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울상담센터 서울상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-9967-5208',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '02--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울정신분석상담연구소',
#   '주소': '서울시 서초구 서초대로51길 13',
#   '좌표': [127.014053866002, 37.4951330668684],
#   '전화번호': '02-592-4530',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울정신분석상담연구소',
#   '주소': '서울시 서초구 서초4동 1694-12 신원빌딩 4층',
#   '좌표': [127.01405511222, 37.4951454105141],
#   '전화번호': '02-592-4530',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '서울해바라기센터',
#   '주소': '서울특별시 종로구 대학로 101 서울대학교병원 함춘회관 지하 101호 / 서울특별시 종로구 대학로8가길 56 동숭빌딩 2층',
#   '좌표': [126.997196437908, 37.5804523853297],
#   '전화번호': '070-4287-0369',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '성균관대학교 일반대학원 심리학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '세리상담센터',
#   '주소': '대구시 수성구 범물동 1277-7(3층) 세리상담센터',
#   '좌표': [128.641485640533, 35.8212129620466],
#   '전화번호': '053-782-8184',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '세움심리상담연구소  세움심리상담연구소',
#   '주소': '경기도 수원시 영통구 권선로882번길 107-32, 2층 202호 (신동)',
#   '좌표': [127.042276987073, 37.2463530219936],
#   '전화번호': '031-202-3812',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '세움심리상담연구소',
#   '주소': '경기도 수원시 영통구 권선로 882번길 107-32. 202호',
#   '좌표': [127.042276987073, 37.2463530219936],
#   '전화번호': '031-202-3812',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '세인임상심리연구소',
#   '주소': '서울시 송파구 송파동 31-2 현대레이크빌 306호',
#   '좌표': [127.106990711098, 37.5107193382697],
#   '전화번호': '02-6287-1275',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '소곤소곤 심리학모임공간 소곤소곤',
#   '주소': '의정부시 호국로 1317번길 18',
#   '좌표': [127.05052428773, 37.7445796522768],
#   '전화번호': '010-5804-1050',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '소향심리상담센터',
#   '주소': '서울 서초구 반포대로14길 71 LG서초에클라트',
#   '좌표': [127.01450471794, 37.4869095170024],
#   '전화번호': '02-522-0275',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '손애리심리연구소',
#   '주소': '대전광역시 서구 둔산로 133, 현대아이텔 418호(둔산동)',
#   '좌표': [127.388774390671, 36.3515866494036],
#   '전화번호': '010-4174-0060',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '순천향대학교 서울병원 정신건강의학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담공간 숨비',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 마음번역소',
#   '주소': '경기도 화성시 동탄대로 551-16 동탄역푸르지오시티',
#   '좌표': [127.096891334834, 37.2031678570961],
#   '전화번호': '070-8064-3136',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 쉴만한 물가',
#   '주소': '경북 포항시 북구 장량로 174번길 6-15 2층',
#   '좌표': [129.398665039949, 36.0810070787643],
#   '전화번호': '054-255-5920',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 아낌',
#   '주소': '강원도 춘천시 동내면 거두택지길 8, 2층',
#   '좌표': [127.752316075125, 37.8527306414589],
#   '전화번호': '033-263-1155',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 연음',
#   '주소': '서울시 광진구 능동로 283 진성빌딩 4층',
#   '좌표': [127.07813388608, 37.5553618559743],
#   '전화번호': '02-464-2830',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 연음',
#   '주소': '능동로 283, 진성빌딩 4층',
#   '좌표': [127.07813388608, 37.5553618559743],
#   '전화번호': '010-6374-0849',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 이랑',
#   '주소': '춘천시 동내면 외솔길 19번길 61, 1층',
#   '좌표': [127.756521272449, 37.8579319884909],
#   '전화번호': '010-7272-9398',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 지음',
#   '주소': '경기도 수원시 영통구 센트럴타운로111 광교서희스타힐스 815호',
#   '좌표': [127.049135270702, 37.2925440566621],
#   '전화번호': '010-9215-8815',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 폭신폭신',
#   '주소': '경기도 고양시 일산서구 주엽동 중앙로 1456 서현프라자 506호',
#   '좌표': [126.758974004688, 37.6715581955538],
#   '전화번호': '031-915-1456',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 함께',
#   '주소': '서울특별시 강남구 선릉로 431.  SK허브 오피스텔 808호',
#   '좌표': [127.049106892969, 37.503435658512],
#   '전화번호': '02-6014-1143',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담센터 헤세드',
#   '주소': '서울시 노원구 한글비석로 384, 225-1호 (중계동, 대호프라자) (상계역 4번출구)',
#   '좌표': None,
#   '전화번호': '02-931-1307',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담소 빛',
#   '주소': '서울시 노원구 동일로 1335  대원빌딩 6층 심리삼담소,법률사무소,인권연구소 빛',
#   '좌표': [127.062272983643, 37.6479984188148],
#   '전화번호': '02-939-1945',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담소 여지',
#   '주소': '경기도 파주시 와석순환로515번길 61, 송림메디컬프라자 8층 810호',
#   '좌표': [126.763191013669, 37.7270005839761],
#   '전화번호': '010-8312-3714',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담연구소 사람과 사람  심리상담연구소 사람과 사람',
#   '주소': '서울시 서초구 효령로97 6층',
#   '좌표': [126.994804407999, 37.4808226285729],
#   '전화번호': '02-6959-7844',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담연구소 사람과 사람 - 과천점',
#   '주소': '경기도 과천시 중앙로 137(가보자빌딩) 4층 404호',
#   '좌표': [126.99173895002, 37.4288054400031],
#   '전화번호': '02-3418-0502',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담연구소 퍼블릭',
#   '주소': '서울특별시 영등포구 여의도동 45-3 NH농협캐피탈빌딩 4층 419호',
#   '좌표': [126.928376261022, 37.5194291401518],
#   '전화번호': '010-9365-8163',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리상담전문기관 공간과 자유',
#   '주소': '대구광역시 수성구 범어동 63-7번지',
#   '좌표': [128.642897587884, 35.8572774946205],
#   '전화번호': '053-746-0910',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리클리닉 아이진 심리클리닉 아이진',
#   '주소': '경기도 성남시 분당구 황새울로 200번기 32, 505호',
#   '좌표': None,
#   '전화번호': '010-4667-2327',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심리학커뮤니티보다 심리학커뮤니티 보다',
#   '주소': '강원도 춘천시 칠전동 2길 16-5번지 1층',
#   '좌표': [127.714678537942, 37.8435430220089],
#   '전화번호': '010-9421-3475',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심상치료본원센터',
#   '주소': '서울시 강남구 역삼동 705-9 삼흥빌딩 1801호',
#   '좌표': [127.04744403408, 37.5046453972508],
#   '전화번호': '02-501-6614',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심설 심리상담센터',
#   '주소': '경기 부천시 상동로117번길 37 409호',
#   '좌표': [126.751348664335, 37.507648370277],
#   '전화번호': '010-3154-2469',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '심클심리상담연구소',
#   '주소': '인천광역시 남동구 구월동 201-30 3층',
#   '좌표': [126.705285958344, 37.449617003555],
#   '전화번호': '010-7741-0916',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '아이자람연구소',
#   '주소': '서울시 송파구 송파대로453 석촌레이크빌 빌딩 602호',
#   '좌표': [127.105303053837, 37.5067695000894],
#   '전화번호': '02-420-3049',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '아주대학교 아주심리상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '031-219-1721',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '아토머스(주) 아토머스(주)',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-8922-9710',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '안산파크심리상담센터, 인천파크심리상담센터',
#   '주소': '인천시 부평구 길주로 633 삼산메디캐슬 3층 303호(7호선 굴포천역)/경기도 안산시 예술대학로 17 중앙노블레스 6층 601호(4호선 중앙역)',
#   '좌표': [126.73288528814, 37.507299288219],
#   '전화번호': '032-505-8288',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '안양시중독관리통합지원센터',
#   '주소': '경기도 안양시 만안구 문예로 48 안양시 만안구보건소 5층',
#   '좌표': [126.932944470333, 37.3858473342855],
#   '전화번호': '031-464-0175',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '없음 .',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '.',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '엘지유플러스',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '02-1544-0010',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '연세휴정신건강의학과 의원, 노규식 공부두뇌연구원',
#   '주소': '서울시 강남구 도곡로 409, 타워엠프리스 빌딩 503호',
#   '좌표': [127.055167024731, 37.4973692137569],
#   '전화번호': '02-556-0990',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '연음 심리상담센터',
#   '주소': '서울시 광진구 능동로 진성빌딩 4층',
#   '좌표': None,
#   '전화번호': '024-464-2830',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '영등포구보건소',
#   '주소': '서울시 영등포구 당산로123 영등포구보건소 5층 힐링캠프상담실',
#   '좌표': [126.896367130558, 37.525963157053],
#   '전화번호': '02-2670-4936',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '오선심리상담센터',
#   '주소': '대전광역시 서구 대덕대로 319(우림필유 916호)',
#   '좌표': [127.378997680022, 36.3614437390277],
#   '전화번호': '0507-1392-0831',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '온리원 종합심리전문센터',
#   '주소': '대구광역시 수성구 상록로 2길 22 허브타워 8F',
#   '좌표': [128.625230883134, 35.8603972376751],
#   '전화번호': '053-744-0201',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '우리심리센터',
#   '주소': '서울시 마포구 독막로 320 태영데시앙빌딩 1206호',
#   '좌표': [126.94787346379, 37.5429644969765],
#   '전화번호': '02-3775-3806',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '울림 심리상담연구소',
#   '주소': '서울시 강남구 삼성동 142-3 LG선릉에클라트B 404호',
#   '좌표': [127.050928670633, 37.5061683570162],
#   '전화번호': '02-562-2145',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '월든3 아카데미',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-4258-8097',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '웰트리심리상담센터 웰트리심리상담센터',
#   '주소': '서울특별시 양천구 신월로 164, 206호',
#   '좌표': [126.842018042503, 37.517760427962],
#   '전화번호': '02-6335-6331',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '육군사관학교 심리경영학과',
#   '주소': '서울시 노원구 화랑로 574 육군사관학교',
#   '좌표': None,
#   '전화번호': '02-2197-2312',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '윤수안임상심리상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '의정부스마일센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이기원 뉴라이프 심리상담센터',
#   '주소': '서울시 송파구 송파대로 28길43',
#   '좌표': [127.12212959012, 37.4957322035314],
#   '전화번호': '02-445-3359',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이수(理修)심리상담센터',
#   '주소': '서울시 동작구 사당로 268 (사당로 1001-33) 2층',
#   '좌표': [126.977419577723, 37.4836183977353],
#   '전화번호': '02-523-5283',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이안정신건강의학과의원',
#   '주소': '세종특별자치시 한누리대로 273 새롬씨티 402호',
#   '좌표': [127.256485046117, 36.4885263268503],
#   '전화번호': '044-999-1102',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이음 심리상담연구소',
#   '주소': '서울시 중구 장충단로 8길12(구 장충동 35-5 대한조산협회) 제이원 빌딩 4층',
#   '좌표': [127.007116142497, 37.5616925819688],
#   '전화번호': '02-6654-4520',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이음과닿음심리상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-8673-0189',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이해와 공감 심리상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-4189-2090',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이해와 공감 심리상담센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-4288-0089',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이해와공감 심리상담센터',
#   '주소': '서울시 서초구 강남대로 224 양재한신휴플러스202호',
#   '좌표': [127.035117473843, 37.4840177269747],
#   '전화번호': '010-4288-0089',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이화심리상담센터',
#   '주소': '서울시 도봉구 창동 331-2 중앙빌딩 402호',
#   '좌표': [127.046078777153, 37.6520515399516],
#   '전화번호': '02-999-5232',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '이화여자대학교 아동발달센터',
#   '주소': '서울시 서대문구 성산로 533 하늬솔빌딩 B동 2층',
#   '좌표': [126.944567132066, 37.564145990654],
#   '전화번호': '02-3277-3268',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '인천북부아동보호전문기관',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '인천서부교육지원청Wee센터',
#   '주소': '인천광역시 계양구 장제로948번길 13 양촌중학교 5층 인천서부교육지원청 Wee센터',
#   '좌표': [126.745004813854, 37.5503270793854],
#   '전화번호': '010-9672-8426',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '인천스마일센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-2598-2574',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '인천참사랑병원',
#   '주소': '인천광역시 서구 원창로 240번길 6 인천참사랑병원 신관 1층 킬리안 연구소',
#   '좌표': [126.67566988929, 37.5168980277841],
#   '전화번호': '032-573-9112',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '인천해바라기센터(아동)',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '032-423-1375',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '일랑심리상담센터',
#   '주소': '서울시 마포구 백범로 202(마포케이씨씨웰츠타워) 4층',
#   '좌표': [126.952468627776, 37.5428481347733],
#   '전화번호': '010-2830-3272',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '일상 임상심리상담소 (070-4262-1511)',
#   '주소': '서울시 송파구 백제고분로 353, 우전빌딩 401호',
#   '좌표': [127.105321004211, 37.5046532038832],
#   '전화번호': '070-4262-1511',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '임상심리센터 이음',
#   '주소': '대구 수성구 달구벌대로 3087번지 4층',
#   '좌표': [128.694730452776, 35.8432039682571],
#   '전화번호': '053-794-0337',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '임상심리전문가그룹 마인드웍스',
#   '주소': '강남구 테헤란호 311 삼성제일빌딩 1718호',
#   '좌표': None,
#   '전화번호': '02-501-5150',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '임상심리전문가그룹 마인드웍스',
#   '주소': '테헤란로 309 삼성제일빌딩 1718호',
#   '좌표': [127.04443196555, 37.5035572530344],
#   '전화번호': '02-501-5150',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '임선영 심리상담연구소',
#   '주소': '서울시 양천구 목동동로 293 현대41타워 2907호',
#   '좌표': [126.875771989415, 37.5281783139269],
#   '전화번호': '02-6671-9090',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '자유연심리행동치료센터',
#   '주소': '서울시 강남구 신사동 576-10 삼구빌딩 206호',
#   '좌표': [127.026910323507, 37.5248038017836],
#   '전화번호': '02-6956-1000',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '자유ON심리상담센터/ACT인지행동치료연구소',
#   '주소': '대전 서구 1417 둔산더리치빌',
#   '좌표': None,
#   '전화번호': '010-3055-4279',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '전라북도아동보호전문기관',
#   '주소': '팔달로 77 2층 거점 심리지원팀',
#   '좌표': [127.015694751547, 37.2798256815894],
#   '전화번호': '010-6222-0851',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '전북대학교 심리코칭연구소',
#   '주소': '전북대학교 인문사회관',
#   '좌표': None,
#   '전화번호': '010-4106-4146',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '전북대학교 일반대학원 심리학과',
#   '주소': '전북 전주시 덕진구 백제대로 567',
#   '좌표': [127.131589859351, 35.8411407038626],
#   '전화번호': '010-2703-2036',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '제주특별자치도교육청 학생건강증진추진단',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '064-710-0053',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '중앙대학교 일반대학원 심리학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '중앙대학교병원 게임과몰입힐링센터',
#   '주소': '서울 동작구 흑석동 224-1 중앙대학교병원 다정관 4층 3413호',
#   '좌표': [126.96086256289, 37.5070485389922],
#   '전화번호': '070-5001-0726',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '중앙대학교병원',
#   '주소': '서울시 동작구 흑석로 102 중앙대학교병원',
#   '좌표': [126.960421779226, 37.506038005044],
#   '전화번호': '02-1800-1114',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '지우심리상담센터',
#   '주소': '강원도 원주시 서원대로 380, 노빌리티타워 3층 지우심리상담센터',
#   '좌표': [127.947514433889, 37.3316833102585],
#   '전화번호': '033-744-1579',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '진안군정신건강복지센터',
#   '주소': '전북 진안군 진안읍 진무로 1189 진안군보건소 내',
#   '좌표': [127.434774836735, 35.7973085385],
#   '전화번호': '063-430-8578',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '차의과학대학교 일반대학원 의학과 임상상담심리전공',
#   '주소': '경기도 포천시 해룡로 120 차 의과학대학교(우편번호 : 11160)',
#   '좌표': [127.13750482624, 37.8559879768899],
#   '전화번호': '031-850-8982',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '참누리정신건강상담센터 참누리정신건강상담센터',
#   '주소': '대구광역시 북구 대학로 133 3층(산격동)',
#   '좌표': [128.612866255677, 35.8961363743727],
#   '전화번호': '053-959-9925',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '참마음심리상담센터',
#   '주소': '서울시 강남구 선릉로 76길 5-7 장원하이츠빌라',
#   '좌표': [127.050951384082, 37.5014799653727],
#   '전화번호': '02-772-9175',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '초당대학교 사회복지상담학과',
#   '주소': '전남 무안군 무안읍 무안로 380 초당대학교 사회복지상담학과',
#   '좌표': [126.470266451147, 34.980047336493],
#   '전화번호': '061-450-1612',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '초록어린이 상담소',
#   '주소': '서울특별시 강서구 초록마을로8길 52, 101(현대빌라 나동)',
#   '좌표': None,
#   '전화번호': '02-784-9599',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '최소영심리치료센터',
#   '주소': '세종시 나성북로 21 센트럴타워 501호',
#   '좌표': [127.258945240294, 36.4898161563742],
#   '전화번호': '044-863-7275',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '최영미마음상담센터',
#   '주소': '광주광역시 북구 우산동 207-11번지 이상클리닉빌딩 4층',
#   '좌표': [126.925131783731, 35.1733248222618],
#   '전화번호': '062-263-7942',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '최효주 임상심리센터',
#   '주소': '서울 성동구 연무장13길9, 5층 5호',
#   '좌표': [127.058219269012, 37.5425836810163],
#   '전화번호': '010-8995-5368',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '춘천스마일센터',
#   '주소': '강원도 춘천시 동내면 공지로 70-67',
#   '좌표': [127.752091243189, 37.8544670937186],
#   '전화번호': '033-255-1295',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '춘천임상심리연구소',
#   '주소': '강원 춘천시 스포츠타운길 528-12, 솔3호',
#   '좌표': [127.71443298141, 37.8677792812404],
#   '전화번호': '033-255-1533',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '충북대학교 일반대학원 심리학과',
#   '주소': '충북 청주시 서원구 충대로1 사회과학대학',
#   '좌표': [127.455076764458, 36.6300443933522],
#   '전화번호': '043-261-2185',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '충북대학교병원 충북대학교병원 행동발달증진센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '043-269-7878',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '충주교육지원청 마음건강증진센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '치유심리상담센터 치유심리상담센터',
#   '주소': '서울특별시 강남구 테헤란로25길 40, 2층 치유심리상담센터(역삼동)',
#   '좌표': [127.0350254291, 37.5031273933305],
#   '전화번호': '02-6959-7904',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '킬리안 정서행동연구소',
#   '주소': '인천광역시 서구 원창로 240번길 6, 1층 킬리안 정서행동연구소',
#   '좌표': [126.67566988929, 37.5168980277841],
#   '전화번호': '032-573-9112',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '틔움심리상담연구소',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-3274-2379',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '파크심리상담센터 안산직영점',
#   '주소': '경기도 안산시 단원구 고잔동 534-3 안산중앙노블레스 6층(4호선 중앙역)',
#   '좌표': [126.836512919625, 37.3186623630936],
#   '전화번호': '031-405-8255',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '포티파이 포티파이',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '푸른숲심리상담센터 부설 임상심리연구소',
#   '주소': '서울시 서초구 서초중앙로8길. 17. 3층',
#   '좌표': [127.01633857201, 37.4867883623402],
#   '전화번호': '02-597-2003',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '푸른존',
#   '주소': '서울시 강북구 솔매로49길 6(미아동)',
#   '좌표': [127.027012540748, 37.6268313146788],
#   '전화번호': '02-944-5811',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '학습&amp;마음 심리상담센터',
#   '주소': '충남 천안시 서북구 불당동 1112번지 202호',
#   '좌표': [127.107353253163, 36.8022752329618],
#   '전화번호': '041-558-3837',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '학습과사랑 임상심리연구소',
#   '주소': '경기도 성남시 분당구 정자동 두산위브 파빌리온 A동 717호',
#   '좌표': None,
#   '전화번호': '031-785-3987',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한결심리상담센터',
#   '주소': '서울시 양천구 신정동 1009-4 유앤미법조빌딩 6층',
#   '좌표': [126.863991174662, 37.5227127432255],
#   '전화번호': '02-2690-9413',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국 트라우마 연구교육원 한국트라우마연구교육원',
#   '주소': '서울특별시 영등포구 63로 36 리버타워 4층 401호 한국 트라우마 연구교육원',
#   '좌표': [126.938610362668, 37.5194206669589],
#   '전화번호': '02-6326-1119',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국도박문제관리센터 광주센터',
#   '주소': '광주광역시 북구 운용로 79 3F',
#   '좌표': None,
#   '전화번호': '070-7733-8256',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국상담임상심리센터',
#   '주소': '서울 종로구 삼일대로 30길 23 , 517호(비즈웰종로오피스텔)',
#   '좌표': [126.988775780571, 37.574475499893],
#   '전화번호': '010-2765-2512',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국심리연구소 대전심리상담센터',
#   '주소': '대전 동구 동서대로 1688, 빅플러스타워504호 (성남동)',
#   '좌표': [127.437440129328, 36.3488529467883],
#   '전화번호': '042-226-3476',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국영성심리상담센터 한국트숨센터',
#   '주소': '서울 강남구 논현로12길 19-6 지하',
#   '좌표': [127.049109072179, 37.4753284532679],
#   '전화번호': '070-4806-8774',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국청소년상담복지개발원 기획전략부',
#   '주소': '부산시 해운대구 센텀중앙로 79 센텀사이언스파크',
#   '좌표': [129.126513499207, 35.1740782852492],
#   '전화번호': '051-662-3023',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한국EMDR트라우마센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '031-213-7705',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한림대학교',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한림대학교 동탄성심병원 정신건강의학과',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '031-8086-2344',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '한림대학교 일반대학원 심리학과',
#   '주소': '강원 춘천시 한림대학길1 한림대학교 심리학과',
#   '좌표': [127.734957299984, 37.885428658608],
#   '전화번호': '033-248-1721',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '해솔 심리상담센터',
#   '주소': '대구시 수성구 매호동 시지우방하이츠 상가 2층',
#   '좌표': None,
#   '전화번호': '053-754-4468',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '해인정신건강상담센터',
#   '주소': '대구광역시 중구 명덕로 261 회당빌딩 2층',
#   '좌표': [128.598600695569, 35.8557990307992],
#   '전화번호': '053-425-0425',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '해피언스',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '010-8700-8449',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '행복생활심리상담센터 행복생활심리상담센터',
#   '주소': '대구광역시 중구 달구벌대로440길7, 4층',
#   '좌표': [128.603893142997, 35.8624976906007],
#   '전화번호': '053-655-8357',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': '호원대학교',
#   '주소': '군산시 임피면',
#   '좌표': [126.850478226788, 35.9826008554518],
#   '전화번호': '010-5657-2875',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'E&amp;C심리상담학습센터',
#   '주소': '대구 남구 이천로 148',
#   '좌표': [128.598686460817, 35.8542819840911],
#   '전화번호': '--',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'LG유플러스 모바일광주고객센터 심리상담실',
#   '주소': '광주광역시 서구 무진대로 951 6층 심리상담실',
#   '좌표': [126.88460924142, 35.1616156369203],
#   '전화번호': '062-601-7272',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'Mindbind',
#   '주소': 'Singapore',
#   '좌표': None,
#   '전화번호': '65-9732-9242',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'MK 내마음 클리닉',
#   '주소': '언주로 120 도곡동 인스토피아 708호',
#   '좌표': [127.051277087103, 37.4867571008939],
#   '전화번호': '010-4321-4894',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'sk 이노베이션 하모니아 상담코칭센터',
#   '주소': '',
#   '좌표': None,
#   '전화번호': '',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'SK주식회사',
#   '주소': '경기도 성남시 분당구 성남대로343번길 9 SK유타워',
#   '좌표': [127.106595520421, 37.3663641005928],
#   '전화번호': '061-797-9238',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'SK하이닉스',
#   '주소': '충북시 흥덕구 2순환로 959',
#   '좌표': None,
#   '전화번호': '043-907-7623',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'The 봄 심리상담센터',
#   '주소': '인천시 미추홀구 아암대로',
#   '좌표': None,
#   '전화번호': '010-3755-4051',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'The봄 심리상담센터',
#   '주소': '경기도 부천시 부천로 3번길 48, 피노키오 상가 602호',
#   '좌표': [126.78030443302, 37.4853704920718],
#   '전화번호': '032-655-1275',
#   '홈페이지': None},
#  {'공공/민간': '민간',
#   '기관구분': '상담소',
#   '기관명': 'Therapyinkorea.com 영어 &amp; 한글 심리상담',
#   '주소': '도화동 560 태영데시앙루브 오피스텔',
#   '좌표': [126.947855469473, 37.5429684534296],
#   '전화번호': '010-8760-9582',
#   '홈페이지': None}]

# %%
import requests

def get_ip():
    response = requests.get('https://api64.ipify.org?format=json').json()
    return response["ip"]
def get_location():
    ip_address = get_ip()
    response = requests.get(f'https://ipapi.co/{ip_address}/json/').json()
    location_data = {
        "ip": ip_address,
        "city": response.get("city"),
        "region": response.get("region"),
        "country": response.get("country_name"),
        "latitude": response.get('latitude'),
        "longitude": response.get('longitude')
    }
    return location_data


print(get_location())

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59f71f48-e620-40de-82b6-60c121211e54' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
