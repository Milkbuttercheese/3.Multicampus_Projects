# %%
import pandas as pd
import numpy as np

# %%
df_01 = pd.read_csv('./data/k_drive.csv', encoding ='cp949')

# %%
df_01.drop(['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
       'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
       'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
       'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
       'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
       'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
       'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
       'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
       'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
       'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
       'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
       'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
       'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54'], axis=1,inplace=True)

# %%
df_01.dropna(how='all')
# Out:
#         기간       응시인원     합격인원        합격률
# 0   2001.0  2,011,798  617,405  30.689214
# 1   2002.0    351,510  171,245  48.716964
# 2   2003.0    247,140  108,046  43.718540
# 3   2004.0    238,609   93,810  39.315365
# 4   2005.0    236,949   98,328  41.497537
# 5   2006.0    185,420   75,914  40.941646
# 6   2007.0    192,103   83,063  43.238783
# 7   2008.0    192,537   91,042  47.285457
# 8   2009.0    212,617   90,075  42.364910
# 9   2010.0    175,347   72,340  41.255339
# 10  2011.0    186,841   83,471  44.674884
# 11  2012.0    190,757   78,399  41.000000
# 12  2013.0    173,285   71,835  41.000000
# 13  2014.0    182,316   74,962  41.000000
# 14  2015.0    189,869  129,326  68.000000
# 15  2016.0    202,083   82,778  41.000000
# 16  2017.0    145,862   60,355  41.000000
# 17  2018.0    140,274   56,800  40.000000
# 18  2019.0    151,646   57,156  38.000000
# 19  2020.0    154,583   52,131  34.000000

# %%
df_02 = pd.read_csv('./data/korea.csv', encoding ='cp949')

# %%
df_02.dropna(how='all')
# Out:
#       기간     사고건수   사망명수       사망률
# 0   2001  260,579  8,097  3.107311
# 1   2002  231,026  7,222  3.126055
# 2   2003  240,832  7,212  2.994619
# 3   2004  220,755  6,563  2.972979
# 4   2005  214,171  6,376  2.977060
# 5   2006  213,745  6,327  2.960069
# 6   2007  211,662  6,166  2.913135
# 7   2008  215,822  5,870  2.719834
# 8   2009  231,990  5,838  2.516488
# 9   2010  226,878  5,505  2.426414
# 10  2011  221,711  5,229  2.358476
# 11  2012  223,656  5,392  2.410845
# 12  2013  215,354  5,092  2.364479
# 13  2014  223,552  4,762  2.130153
# 14  2015  232,035  4,621  1.991510
# 15  2016  220,917  4,292  1.942811
# 16  2017  216,335  4,185  1.934500
# 17  2018  217,148  3,781  1.741209
# 18  2019  229,600  3,349  1.458624

# %%
df_03 = pd.read_csv('./data/k_g.csv', encoding ='cp949')

# %%
df_03.dropna(how='all')
# Out:
#         기간       응시인원     합격인원        합격률     사고건수   사망명수       사망률
# 0   2001.0  2,011,798  617,405  30.689214  260,579  8,097  3.107311
# 1   2002.0    351,510  171,245  48.716964  231,026  7,222  3.126055
# 2   2003.0    247,140  108,046  43.718540  240,832  7,212  2.994619
# 3   2004.0    238,609   93,810  39.315365  220,755  6,563  2.972979
# 4   2005.0    236,949   98,328  41.497537  214,171  6,376  2.977060
# 5   2006.0    185,420   75,914  40.941646  213,745  6,327  2.960069
# 6   2007.0    192,103   83,063  43.238783  211,662  6,166  2.913135
# 7   2008.0    192,537   91,042  47.285457  215,822  5,870  2.719834
# 8   2009.0    212,617   90,075  42.364910  231,990  5,838  2.516488
# 9   2010.0    175,347   72,340  41.255339  226,878  5,505  2.426414
# 10  2011.0    186,841   83,471  44.674884  221,711  5,229  2.358476
# 11  2012.0    190,757   78,399  41.000000  223,656  5,392  2.410845
# 12  2013.0    173,285   71,835  41.000000  215,354  5,092  2.364479
# ...

# %%
df_03 = df_03.dropna()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# 합격률 막대그래프
plt.figure(figsize=(12,6))
plt.bar(df_01['기간'], df_01['합격률'])
plt.title("합격률", size = "20")
plt.ylim(28,70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 사망률 막대그래프
plt.figure(figsize=(12,6))
plt.bar(df_02['기간'], df_02['사망률'])
plt.title("사망률", size = "20")
plt.ylim(1.2,3.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_03['합격률'], df_03['사망률'], s=50)
plt.xlabel('합격률')
plt.ylabel('사망률')
plt.title("합격률 대비 사망률", size = "15")
plt.grid()

# %%
df_03['사고건수']=df_03['사고건수'].str.replace(pat=r'[^A-Za-z0-9]', repl='', regex=True)

# %%
df_03 = df_03.astype({'사고건수' : 'int'})

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_03['합격률'], df_03['사고건수'], s=50)
plt.xlabel('합격률')
plt.ylabel('사고건수')
plt.title("합격률 대비 사고건수", size = "15")
plt.grid()

# %% [markdown]
# 결론 : 2011년 쉬워진 운전면허 시험과 합격률, 사망률, 사고건수 간의 연관성이 없어보임
